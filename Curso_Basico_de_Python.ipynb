# %% [markdown]
# <a href="https://colab.research.google.com/github/flaviosilvaf8/Projetos-Python/blob/main/Curso_Basico_de_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Lógica de programação

# Passo 0 - Entender o desafio que você quer resolver

# Passo 1 - Percorrer todos os arquivos da pasta base de dados (Pasta Vendas)
import os
import pandas as pd

lista_arquivo = os.listdir("/content/drive/MyDrive/Curso Básico de Python/Vendas")
display(lista_arquivo)
# Out:
# ['Vendas - Curitiba.csv',
#  'Devolucoes - Fortaleza.csv',
#  'Devolucoes - Goiás.csv',
#  'Devolucoes - Curitiba.csv',
#  'Vendas - Fortaleza.csv',
#  'Devolucoes - Porto Alegre.csv',
#  'Devolucoes - São Paulo.csv',
#  'Devolucoes - Salvador.csv',
#  'Vendas - Belo Horizonte.csv',
#  'Vendas - Goiás.csv',
#  'Vendas - Recife.csv',
#  'Vendas - Salvador.csv',
#  'Vendas - Porto Alegre.csv',
#  'Vendas - Rio de Janeiro.csv',
#  'Vendas - São Paulo.csv',
#  'Devolucoes - Recife.csv',
#  'Devolucoes - Belo Horizonte.csv',
#  'Devolucoes - Rio de Janeiro.csv']

# %%
tabela_total = pd.DataFrame()

# Passo 2 - Importar as bases de dados de vendas
for arquivo in lista_arquivo:
  # se tem "Vendas" no nome do arquivo, então
  if "Vendas" in arquivo:
    # importar o arquivo
    tabela = pd.read_csv(f"/content/drive/MyDrive/Curso Básico de Python/Vendas/{arquivo}")
    tabela_total = pd.concat([tabela])

# Passo 3 - Tratar / Compilar as bases de dados
display(tabela_total)
# Out:
#       Unnamed: 0     SKU     Produto  Quantidade Vendida Primeiro Nome  \
# 0              5  HL1918      iPhone                   4         Sarah
# 1              6  HL7348  SmartWatch                   3     Alexandre
# 2              9  HL1148      Câmera                   3       Camille
# 3             10  HL1918      iPhone                   3          Alon
# 4             18  HL8851    Notebook                   4       Leandro
# ...          ...     ...         ...                 ...           ...
# 2221        9981  HL7348  SmartWatch                   4          João
# 2222        9984  HL1918      iPhone                   4          Itai
# 2223        9985  HL1918      iPhone                   1     Guilherme
# 2224        9991  HL7348  SmartWatch                   5       Antônio
# 2225        9996  HL4379   Televisão                   5          Caio
#
#       Sobrenome        Data       Loja  Preco Unitario  Unnamed: 8
# 0         Souza   2/14/2018  São Paulo            5300         NaN
# 1     Rodriguez   5/20/2018  São Paulo            1400         NaN
# 2         Silva   3/26/2018  São Paulo            2100         NaN
# 3      Palmeira   11/6/2018  São Paulo            5300         NaN
# 4     Rodrigues    8/6/2018  São Paulo            3500         NaN
# ...         ...         ...        ...             ...         ...
# 2221     Junior   4/14/2018  São Paulo            1400         NaN
# 2222     Puntel    5/2/2018  São Paulo            5300         NaN
# 2223     Vianna   3/18/2018  São Paulo            5300         NaN
# 2224     Soares  11/21/2018  São Paulo            1400         NaN
# 2225     Moraes   1/22/2018  São Paulo            2500         NaN
#
# [2226 rows x 10 columns]

# %%
# Passo 4 - Calcular o produto mais vendido (em quantidade)
tabela_produtos = tabela_total.groupby('Produto').sum()
tabela_produtos = tabela_produtos[["Quantidade Vendida"]].sort_values(by="Quantidade Vendida", ascending=False)
display(tabela_produtos)
# Out:
# <ipython-input-6-5ba6603b89ac>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tabela_produtos = tabela_total.groupby('Produto').sum()
#             Quantidade Vendida
# Produto
# iPhone                    1981
# Televisão                 1287
# Android                    758
# Notebook                   722
# SmartWatch                 654
# Câmera                     653
# Tablet                     619

# %%
# Passo 5 - Calcular o produto que mais faturou (em faturamento)
tabela_total['Faturamento'] = tabela_total['Quantidade Vendida'] * tabela_total['Preco Unitario']

tabela_faturamento = tabela_total.groupby('Produto').sum()
tabela_faturamento = tabela_faturamento[["Faturamento"]].sort_values(by="Faturamento", ascending=False)
display(tabela_faturamento)
# Out:
# <ipython-input-7-bf3014426bbf>:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tabela_faturamento = tabela_total.groupby('Produto').sum()
#             Faturamento
# Produto
# iPhone         10499300
# Televisão       3217500
# Android         2577200
# Notebook        2527000
# Câmera          1371300
# Tablet           990400
# SmartWatch       915600

# %%
# Passo 6 - Calcular a loja/cidade que mais vendeu (em faturamento)
tabela_lojas = tabela_total.groupby('Loja').sum()
tabela_lojas = tabela_lojas[['Faturamento']]
display(tabela_lojas)
# Out:
# <ipython-input-9-bc66081481c4>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tabela_lojas = tabela_total.groupby('Loja').sum()
#            Faturamento
# Loja
# São Paulo     22098300
